# %% [markdown]
# # N-Grams from Text

# %%
import pandas as pd
import numpy as np
from nltk.tokenize import RegexpTokenizer
from nltk.util import ngrams
from operator import itemgetter # The operator module exports a set of efficient functions corresponding to the intrinsic operators of Python. For example, operator.add(x, y) is equivalent to the expression x + y.

from nltk.corpus import stopwords
import string
from nltk import bigrams
from nltk import FreqDist
from nltk import bigrams

from nltk.stem import (PorterStemmer, LancasterStemmer)
from nltk.stem.snowball import SnowballStemmer # This is "Porter 2" and is considered the optimal stemmer.

from nltk import WordNetLemmatizer

from nltk.corpus import words

# %%
tweets_dataset = pd.read_csv("../input/tweets_dataset_all.csv")
tweets_dataset.tail(4)
# Out:
#                                                      text
# 149564                    Off a Xanax have some drunk sex
# 149565  I’ve heard he had an Adderall and cocaine prob...
# 149566  Si vous avez de la vaisselle à faire appelez m...
# 149567   “portuguese is like spanish in xanax ” DE VERDAD

# %%
def n_upper_chars(string):
    return sum(1 for c in string if c.isupper())

# %%
tweets_dataset['upper'] = tweets_dataset['text'].apply(lambda x: n_upper_chars(x))

# %%
tweets_dataset['text'] = tweets_dataset['text'].apply(lambda x: x.lower())

# %%
tweets_dataset[tweets_dataset.upper > 0].count()
# Out:
# text     46626
# upper    46626
# dtype: int64

# %%
def standardize_text(df, text_field):
    df[text_field] = df[text_field].str.replace(r"http\S+", "")
    df[text_field] = df[text_field].str.replace(r"http", "")
    df[text_field] = df[text_field].str.replace(r"(\d)", "")
    df[text_field] = df[text_field].str.replace(r"@\S+", "")
    df[text_field] = df[text_field].str.replace(r"[^A-Za-z0-9(),!?@\'\`\"\_\n]", " ")
    df[text_field] = df[text_field].str.replace(r"@", "at")
    df[text_field] = df[text_field].str.lower()
    return df

df_clean_text = standardize_text(tweets_dataset, "text")

# %%
def drug_name(text):
    
    drugName = np.nan
    if 'adderall' in text:
        drugName = 'Adderall'
    elif 'prozac' in text: 
        drugName = 'Prozac'
    elif 'xanax' in text:
        drugName = 'Xanax'
        
    return drugName

# %%
tweets_dataset["drugName"] = tweets_dataset["text"].apply(drug_name)

# %%
tweets_dataset[tweets_dataset.drugName.isna()].text.count()
# Out:
# 19735

# %%
def useless(text):
    
    useless = np.nan
    if 'realdonaldtrum' in text:
        useless = 'realDonaldTrump'
    elif 'onaldTrum p' in text:
        useless = 'realDonaldTrump'
        
    return useless

# %%
tweets_dataset["useless"] = tweets_dataset["text"].apply(useless)

# %%
tweets_dataset[tweets_dataset["useless"] == 'realDonaldTrump'].useless.count()
# Out:
# 1717

# %%
def tokenizer(text):
    tokenizer = RegexpTokenizer("[a-zA-Z'`éèî]+")
    s_tokenized = tokenizer.tokenize(text)
    return s_tokenized

# %%
tweets_dataset['tokens'] = tweets_dataset['text'].apply(lambda x: tokenizer(x))

# %%
tweets_dataset.to_csv("../output/tweets_dataset_all.csv", index=False)
tweets_dataset.head()
# Out:
#                                                 text  upper  drugName useless  \
# 0  i am buying spy put amd leaving dsx alone that...      0    Prozac     NaN
# 1  if my psychiatrist forgets to call in my adder...      0  Adderall     NaN
# 2     i wa da person on xanax i ain have nun to lose      0     Xanax     NaN
# 3  came from being a xanax addict to a bad as bit...      0     Xanax     NaN
# 4  what is going on with violent and super sleazy...      0  Adderall     NaN
#
#                                               tokens
# 0  [i, am, buying, spy, put, amd, leaving, dsx, a...
# 1  [if, my, psychiatrist, forgets, to, call, in, ...
# 2  [i, wa, da, person, on, xanax, i, ain, have, n...
# 3  [came, from, being, a, xanax, addict, to, a, b...
# 4  [what, is, going, on, with, violent, and, supe...

# %%
def n_grams(tokens):
    generated_4grams = []

    for word in tokens:
        generated_4grams.append(list(ngrams(word, 4, pad_left=True, pad_right=True, left_pad_symbol='_', right_pad_symbol='_'))) # n = 4.
        generated_4grams = [word for sublist in generated_4grams for word in sublist]
        ng_list_4grams = generated_4grams
        
    for idx, val in enumerate(generated_4grams):
        ng_list_4grams[idx] = ''.join(val)
    ng_list_4grams
    
    freq_4grams = {}

    for ngram in ng_list_4grams:
        if ngram not in freq_4grams:
            freq_4grams.update({ngram: 1})
        else:
            ngram_occurrences = freq_4grams[ngram]
            freq_4grams.update({ngram: ngram_occurrences + 1})

    freq_4grams_sorted = sorted(freq_4grams.items(), key=itemgetter(1), reverse=True)[0:300] # We only keep the 300 most popular n-grams. This was suggested in the original paper written about n-grams.
    return freq_4grams_sorted

# %%
from nltk import everygrams
def ngram_extractor(sent):
    return [''.join(ng) for ng in everygrams(sent.replace(' ', '_ _'), 1, 4) 
            if ' ' not in ng and '\n' not in ng and ng != ('_',)]

# %%
tweets_dataset['ngrams'] = tweets_dataset['text'].apply(lambda x: ngram_extractor(x))

# %%
tweets_dataset.head()
# Out:
#                                                 text  upper  drugName useless  \
# 0  i am buying spy put amd leaving dsx alone that...      0    Prozac     NaN
# 1  if my psychiatrist forgets to call in my adder...      0  Adderall     NaN
# 2     i wa da person on xanax i ain have nun to lose      0     Xanax     NaN
# 3  came from being a xanax addict to a bad as bit...      0     Xanax     NaN
# 4  what is going on with violent and super sleazy...      0  Adderall     NaN
#
#                                               tokens  \
# 0  [i, am, buying, spy, put, amd, leaving, dsx, a...
# 1  [if, my, psychiatrist, forgets, to, call, in, ...
# 2  [i, wa, da, person, on, xanax, i, ain, have, n...
# 3  [came, from, being, a, xanax, addict, to, a, b...
# 4  [what, is, going, on, with, violent, and, supe...
#
#                                               ngrams
# 0  [i, a, m, b, u, y, i, n, g, s, p, y, p, u, t, ...
# 1  [i, f, m, y, p, s, y, c, h, i, a, t, r, i, s, ...
# 2  [i, w, a, d, a, p, e, r, s, o, n, o, n, x, a, ...
# 3  [c, a, m, e, f, r, o, m, b, e, i, n, g, a, x, ...
# 4  [w, h, a, t, i, s, g, o, i, n, g, o, n, w, i, ...

# %%
stopwords.words('english')[:10]
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %%
tweets_dataset.tokens[0]
# Out:
# ['i',
#  'am',
#  'buying',
#  'spy',
#  'put',
#  'amd',
#  'leaving',
#  'dsx',
#  'alone',
#  'that',
#  'lovely',
#  'german',
#  'lady',
#  'is',
#  'bipolar',
#  'and',
#  'need',
#  'some',
#  'prozac',
#  'before',
#  'i',
#  'can',
#  'flirt',
#  'again']

# %%
def cln_tokens(tokens):

    trade_words_condensed = [w.lower() for w in tokens if w.lower() not in stopwords.words('english')]


    punct_combo = [c + "\"" for c in string.punctuation ] + ["\"" + c for c in string.punctuation] + ["xanax","adderall","prozac" ] + [".-", ":-", "..", "..."]
    trade_words_condensed = [w for w in trade_words_condensed if w not in string.punctuation and w not in punct_combo]

    #bi_trade_words_condensed = list(bigrams(trade_words_condensed))
    #bi_fdist = FreqDist(bi_trade_words_condensed)

    return trade_words_condensed

# %%
tweets_dataset['cln_tokens'] = tweets_dataset['tokens'].apply(lambda x: cln_tokens(x))

# %%
tweets_dataset['cln_tokens'][0]
# Out:
# ['buying',
#  'spy',
#  'put',
#  'amd',
#  'leaving',
#  'dsx',
#  'alone',
#  'lovely',
#  'german',
#  'lady',
#  'bipolar',
#  'need',
#  'flirt']

# %%
porter = PorterStemmer()
lancaster = LancasterStemmer()
snowball = SnowballStemmer("english")

def stems_collection(tokens):
    for stemmer in [porter, lancaster, snowball]:
        stems = [stemmer.stem(t) for t in tokens]
    return stems

# %%
tweets_dataset['stem_tokens'] = tweets_dataset['cln_tokens'].apply(lambda x: stems_collection(x))

# %%
tweets_dataset
# Out:
#                                                      text  upper  drugName  \
# 0       i am buying spy put amd leaving dsx alone that...      0    Prozac
# 1       if my psychiatrist forgets to call in my adder...      0  Adderall
# 2          i wa da person on xanax i ain have nun to lose      0     Xanax
# 3       came from being a xanax addict to a bad as bit...      0     Xanax
# 4       what is going on with violent and super sleazy...      0  Adderall
# 5       i went to rehab last summer cuz i wa withdraw ...      0     Xanax
# 6       extremely aerosmith voice im baack back on my ...      0    Prozac
# 7       this is officially an uncomfortable xanax infu...      0     Xanax
# 8                           trump is sharing his adderall      0  Adderall
# 9       he never ever not once ever taken adderall mor...      0  Adderall
# 10      i liked a youtube video unsane the bloat amphe...      0       NaN
# 11      start passing out the xanax it going to be a l...      0     Xanax
# 12      i guess youre not supposed to eat xanax for di...      0     Xanax
# 13      me putting fresh basil some extra spice in my ...      0  Adderall
# 14      have frequent angeryesyou suffer from histrion...      0    Prozac
# 15      demi lovatos mom open up about escaping abusiv...      0     Xanax
# 16      nwa eazye abovethelaw bigpun biggie scarface m...      0     Xanax
# 17      people hate on demi for addiction but half of ...      0     Xanax
# 18      secondly by wired i meant i feel similar to a ...      0       NaN
# 19      you ever pop a couple xanax with a sub and the...      0     Xanax
# 20           she abuse her xanax prescription is my guess      0     Xanax
# 21      taking xanax red ha to win or were in serious ...      0     Xanax
# 22      flight anxiety cure xanax and two mic ultras n...      0     Xanax
# 23      i have watched all network for last month and ...      0    Prozac
# 24      i have xanax for panic attack i hate taking it...      0     Xanax
# 25      between lead exposure and the extraordinarily ...      0  Adderall
# 26      how do u feel about people taking etizolam in ...      0     Xanax
# 27      teen xanax abuse is surgingbaltimore teen drug...      0     Xanax
# 28       have blurry visionyou probably have cause prozac      0    Prozac
# 29      no one know what cause depression the idea tha...      0    Prozac
# ...                                                   ...    ...       ...
# 149538   aral kd nyadepresyong n  gidem de bi prozac i em      4    Prozac
# 149539  que pobre pan ni que la  maraca,desde el proza...     55    Prozac
# 149540  very small percentage of people will have incr...      4     Xanax
# 149541  screams i will never forget how she got an add...      0  Adderall
# 149542   is adderall that good i mean u are tweaking b...      6  Adderall
# 149543  me tiene tomando del xanax xq dijo q no me ama...      0     Xanax
# 149544  research how many started out on adderall , or...    103  Adderall
# 149545  today is actually the first day i've ever take...     10    Prozac
# 149546  c'est bien de te convaincre d'avoir un semblan...      1     Xanax
# 149547  not really, i mean we treat them better than m...      3     Xanax
# 149548  trump is playing three dimensional chess in th...      4  Adderall
# 149549  trump is too lit up on adderall to know where ...     15  Adderall
# 149550  amber, i m thinking rick offered you the   xan...      4     Xanax
# 149551  finch, be careful on a cold turkey quit of flu...      5       NaN
# 149552  did you know that florida believes that steroi...      0     Xanax
# 149553   mg of cymbalta  i switched years ago from lex...     10    Prozac
# 149554  going to pop some xanax , hop in a tanning bed...      2     Xanax
# 149555  don't forget your adderall before your speech ...      2  Adderall
# 149556  just popped an adderall time to write music al...     18  Adderall
# 149557  we're you hallucinating?? does snorting addera...     12  Adderall
# 149558  terrible case  did you listen to grandma's  ca...     15     Xanax
# 149559  while reporting results of that physical talk ...      4  Adderall
# 149560  i always want to answer,  bitch if you really ...      2     Xanax
# 149561  deputies retrieve loaded guns, pounds of marij...     10     Xanax
# 149562  breaking  attorney general geoffrey cox has be...     28     Xanax
# 149563  alcohol and xanax heals depression     tempora...      3     Xanax
# 149564                    off a xanax have some drunk sex      2     Xanax
# 149565  i ve heard he had an adderall and cocaine prob...      5  Adderall
# 149566  si vous avez de la vaisselle   faire appelez m...      3     Xanax
# 149567    portuguese is like spanish in xanax   de verdad      8     Xanax
#
#        useless                                             tokens  \
# 0          NaN  [i, am, buying, spy, put, amd, leaving, dsx, a...
# 1          NaN  [if, my, psychiatrist, forgets, to, call, in, ...
# 2          NaN  [i, wa, da, person, on, xanax, i, ain, have, n...
# 3          NaN  [came, from, being, a, xanax, addict, to, a, b...
# 4          NaN  [what, is, going, on, with, violent, and, supe...
# 5          NaN  [i, went, to, rehab, last, summer, cuz, i, wa,...
# 6          NaN  [extremely, aerosmith, voice, im, baack, back,...
# 7          NaN  [this, is, officially, an, uncomfortable, xana...
# 8          NaN                [trump, is, sharing, his, adderall]
# 9          NaN  [he, never, ever, not, once, ever, taken, adde...
# 10         NaN  [i, liked, a, youtube, video, unsane, the, blo...
# 11         NaN  [start, passing, out, the, xanax, it, going, t...
# 12         NaN  [i, guess, youre, not, supposed, to, eat, xana...
# 13         NaN  [me, putting, fresh, basil, some, extra, spice...
# 14         NaN  [have, frequent, angeryesyou, suffer, from, hi...
# 15         NaN  [demi, lovatos, mom, open, up, about, escaping...
# 16         NaN  [nwa, eazye, abovethelaw, bigpun, biggie, scar...
# 17         NaN  [people, hate, on, demi, for, addiction, but, ...
# 18         NaN  [secondly, by, wired, i, meant, i, feel, simil...
# 19         NaN  [you, ever, pop, a, couple, xanax, with, a, su...
# 20         NaN  [she, abuse, her, xanax, prescription, is, my,...
# 21         NaN  [taking, xanax, red, ha, to, win, or, were, in...
# 22         NaN  [flight, anxiety, cure, xanax, and, two, mic, ...
# 23         NaN  [i, have, watched, all, network, for, last, mo...
# 24         NaN  [i, have, xanax, for, panic, attack, i, hate, ...
# 25         NaN  [between, lead, exposure, and, the, extraordin...
# 26         NaN  [how, do, u, feel, about, people, taking, etiz...
# 27         NaN  [teen, xanax, abuse, is, surgingbaltimore, tee...
# 28         NaN  [have, blurry, visionyou, probably, have, caus...
# 29         NaN  [no, one, know, what, cause, depression, the, ...
# ...        ...                                                ...
# 149538     NaN  [aral, kd, nyadepresyong, n, gidem, de, bi, pr...
# 149539     NaN  [que, pobre, pan, ni, que, la, maraca, desde, ...
# 149540     NaN  [very, small, percentage, of, people, will, ha...
# 149541     NaN  [screams, i, will, never, forget, how, she, go...
# 149542     NaN  [is, adderall, that, good, i, mean, u, are, tw...
# 149543     NaN  [me, tiene, tomando, del, xanax, xq, dijo, q, ...
# 149544     NaN  [research, how, many, started, out, on, addera...
# 149545     NaN  [today, is, actually, the, first, day, i've, e...
# 149546     NaN  [c'est, bien, de, te, convaincre, d'avoir, un,...
# 149547     NaN  [not, really, i, mean, we, treat, them, better...
# 149548     NaN  [trump, is, playing, three, dimensional, chess...
# 149549     NaN  [trump, is, too, lit, up, on, adderall, to, kn...
# 149550     NaN  [amber, i, m, thinking, rick, offered, you, th...
# 149551     NaN  [finch, be, careful, on, a, cold, turkey, quit...
# 149552     NaN  [did, you, know, that, florida, believes, that...
# 149553     NaN  [mg, of, cymbalta, i, switched, years, ago, fr...
# 149554     NaN  [going, to, pop, some, xanax, hop, in, a, tann...
# 149555     NaN  [don't, forget, your, adderall, before, your, ...
# 149556     NaN  [just, popped, an, adderall, time, to, write, ...
# 149557     NaN  [we're, you, hallucinating, does, snorting, ad...
# 149558     NaN  [terrible, case, did, you, listen, to, grandma...
# 149559     NaN  [while, reporting, results, of, that, physical...
# 149560     NaN  [i, always, want, to, answer, bitch, if, you, ...
# 149561     NaN  [deputies, retrieve, loaded, guns, pounds, of,...
# 149562     NaN  [breaking, attorney, general, geoffrey, cox, h...
# 149563     NaN  [alcohol, and, xanax, heals, depression, tempo...
# 149564     NaN            [off, a, xanax, have, some, drunk, sex]
# 149565     NaN  [i, ve, heard, he, had, an, adderall, and, coc...
# 149566     NaN  [si, vous, avez, de, la, vaisselle, faire, app...
# 149567     NaN  [portuguese, is, like, spanish, in, xanax, de,...
#
#                                                    ngrams  \
# 0       [i, a, m, b, u, y, i, n, g, s, p, y, p, u, t, ...
# 1       [i, f, m, y, p, s, y, c, h, i, a, t, r, i, s, ...
# 2       [i, w, a, d, a, p, e, r, s, o, n, o, n, x, a, ...
# 3       [c, a, m, e, f, r, o, m, b, e, i, n, g, a, x, ...
# 4       [w, h, a, t, i, s, g, o, i, n, g, o, n, w, i, ...
# 5       [i, w, e, n, t, t, o, r, e, h, a, b, l, a, s, ...
# 6       [e, x, t, r, e, m, e, l, y, a, e, r, o, s, m, ...
# 7       [t, h, i, s, i, s, o, f, f, i, c, i, a, l, l, ...
# 8       [t, r, u, m, p, i, s, s, h, a, r, i, n, g, h, ...
# 9       [h, e, n, e, v, e, r, e, v, e, r, n, o, t, o, ...
# 10      [i, l, i, k, e, d, a, y, o, u, t, u, b, e, v, ...
# 11      [s, t, a, r, t, p, a, s, s, i, n, g, o, u, t, ...
# 12      [i, g, u, e, s, s, y, o, u, r, e, n, o, t, s, ...
# 13      [m, e, p, u, t, t, i, n, g, f, r, e, s, h, b, ...
# 14      [h, a, v, e, f, r, e, q, u, e, n, t, a, n, g, ...
# 15      [d, e, m, i, l, o, v, a, t, o, s, m, o, m, o, ...
# 16      [n, w, a, e, a, z, y, e, a, b, o, v, e, t, h, ...
# 17      [p, e, o, p, l, e, h, a, t, e, o, n, d, e, m, ...
# 18      [s, e, c, o, n, d, l, y, b, y, w, i, r, e, d, ...
# 19      [y, o, u, e, v, e, r, p, o, p, a, c, o, u, p, ...
# 20      [s, h, e, a, b, u, s, e, h, e, r, x, a, n, a, ...
# 21      [t, a, k, i, n, g, x, a, n, a, x, r, e, d, h, ...
# 22      [f, l, i, g, h, t, a, n, x, i, e, t, y, c, u, ...
# 23      [i, h, a, v, e, w, a, t, c, h, e, d, a, l, l, ...
# 24      [i, h, a, v, e, x, a, n, a, x, f, o, r, p, a, ...
# 25      [b, e, t, w, e, e, n, l, e, a, d, e, x, p, o, ...
# 26      [h, o, w, d, o, u, f, e, e, l, a, b, o, u, t, ...
# 27      [t, e, e, n, x, a, n, a, x, a, b, u, s, e, i, ...
# 28      [h, a, v, e, b, l, u, r, r, y, v, i, s, i, o, ...
# 29      [n, o, o, n, e, k, n, o, w, w, h, a, t, c, a, ...
# ...                                                   ...
# 149538  [a, r, a, l, k, d, n, y, a, d, e, p, r, e, s, ...
# 149539  [q, u, e, p, o, b, r, e, p, a, n, n, i, q, u, ...
# 149540  [v, e, r, y, s, m, a, l, l, p, e, r, c, e, n, ...
# 149541  [s, c, r, e, a, m, s, i, w, i, l, l, n, e, v, ...
# 149542  [i, s, a, d, d, e, r, a, l, l, t, h, a, t, g, ...
# 149543  [m, e, t, i, e, n, e, t, o, m, a, n, d, o, d, ...
# 149544  [r, e, s, e, a, r, c, h, h, o, w, m, a, n, y, ...
# 149545  [t, o, d, a, y, i, s, a, c, t, u, a, l, l, y, ...
# 149546  [c, ', e, s, t, b, i, e, n, d, e, t, e, c, o, ...
# 149547  [n, o, t, r, e, a, l, l, y, ,, i, m, e, a, n, ...
# 149548  [t, r, u, m, p, i, s, p, l, a, y, i, n, g, t, ...
# 149549  [t, r, u, m, p, i, s, t, o, o, l, i, t, u, p, ...
# 149550  [a, m, b, e, r, ,, i, m, t, h, i, n, k, i, n, ...
# 149551  [f, i, n, c, h, ,, b, e, c, a, r, e, f, u, l, ...
# 149552  [d, i, d, y, o, u, k, n, o, w, t, h, a, t, f, ...
# 149553  [m, g, o, f, c, y, m, b, a, l, t, a, i, s, w, ...
# 149554  [g, o, i, n, g, t, o, p, o, p, s, o, m, e, x, ...
# 149555  [d, o, n, ', t, f, o, r, g, e, t, y, o, u, r, ...
# 149556  [j, u, s, t, p, o, p, p, e, d, a, n, a, d, d, ...
# 149557  [w, e, ', r, e, y, o, u, h, a, l, l, u, c, i, ...
# 149558  [t, e, r, r, i, b, l, e, c, a, s, e, d, i, d, ...
# 149559  [w, h, i, l, e, r, e, p, o, r, t, i, n, g, r, ...
# 149560  [i, a, l, w, a, y, s, w, a, n, t, t, o, a, n, ...
# 149561  [d, e, p, u, t, i, e, s, r, e, t, r, i, e, v, ...
# 149562  [b, r, e, a, k, i, n, g, a, t, t, o, r, n, e, ...
# 149563  [a, l, c, o, h, o, l, a, n, d, x, a, n, a, x, ...
# 149564  [o, f, f, a, x, a, n, a, x, h, a, v, e, s, o, ...
# 149565  [i, v, e, h, e, a, r, d, h, e, h, a, d, a, n, ...
# 149566  [s, i, v, o, u, s, a, v, e, z, d, e, l, a, v, ...
# 149567  [p, o, r, t, u, g, u, e, s, e, i, s, l, i, k, ...
#
#                                                cln_tokens  \
# 0       [buying, spy, put, amd, leaving, dsx, alone, l...
# 1       [psychiatrist, forgets, call, im, flipping, tf...
# 2                             [wa, da, person, nun, lose]
# 3       [came, addict, bad, bitch, life, together, im,...
# 4       [going, violent, super, sleazy, democrat, vict...
# 5       [went, rehab, last, summer, cuz, wa, withdraw,...
# 6       [extremely, aerosmith, voice, im, baack, back,...
# 7       [officially, uncomfortable, infused, friday, f...
# 8                                        [trump, sharing]
# 9       [never, ever, ever, taken, moron, hed, never, ...
# 10      [liked, youtube, video, unsane, bloat, ampheta...
# 11                  [start, passing, going, long, summer]
# 12      [guess, youre, supposed, eat, dinner, snort, m...
# 13      [putting, fresh, basil, extra, spice, ramen, n...
# 14      [frequent, angeryesyou, suffer, histrionic, pe...
# 15      [demi, lovatos, mom, open, escaping, abusive, ...
# 16      [nwa, eazye, abovethelaw, bigpun, biggie, scar...
# 17      [people, hate, demi, addiction, half, yall, po...
# 18      [secondly, wired, meant, feel, similar, wa, ls...
# 19      [ever, pop, couple, sub, go, session, nope, iv...
# 20                           [abuse, prescription, guess]
# 21      [taking, red, ha, win, serious, trouble, hard,...
# 22      [flight, anxiety, cure, two, mic, ultras, nofear]
# 23      [watched, network, last, month, almost, despai...
# 24      [panic, attack, hate, taking, feel, dragged, f...
# 25      [lead, exposure, extraordinarily, high, incide...
# 26      [u, feel, people, taking, etizolam, usa, truly...
# 27      [teen, abuse, surgingbaltimore, teen, drug, us...
# 28                   [blurry, visionyou, probably, cause]
# 29      [one, know, cause, depression, idea, chemical,...
# ...                                                   ...
# 149538    [aral, kd, nyadepresyong, n, gidem, de, bi, em]
# 149539  [que, pobre, pan, ni, que, la, maraca, desde, ...
# 149540  [small, percentage, people, increased, excitab...
# 149541  [screams, never, forget, got, 'addiction', spa...
# 149542  [good, mean, u, tweaking, bigly, wtf, word, sa...
# 149543  [tiene, tomando, del, xq, dijo, q, ama, cc, un...
# 149544  [research, many, started, ritalin, young, age,...
# 149545  [today, actually, first, day, i've, ever, take...
# 149546  [c'est, bien, de, te, convaincre, d'avoir, un,...
# 149547  [really, mean, treat, better, way, sustainable...
# 149548  [trump, playing, three, dimensional, chess, fo...
# 149549  [trump, lit, know, russianasset, impeachthemf,...
# 149550  [amber, thinking, rick, offered, chill, fuck, ...
# 149551  [finch, careful, cold, turkey, quit, fluoxetin...
# 149552  [know, florida, believes, steroid, abuse, prov...
# 149553  [mg, cymbalta, switched, years, ago, lexapro, ...
# 149554  [going, pop, hop, tanning, bed, forget, almost...
# 149555            [forget, speech, tonight, sniff, sniff]
# 149556  [popped, time, write, music, alll, night, yyee...
# 149557  [we're, hallucinating, snorting, bring, halluc...
# 149558  [terrible, case, listen, grandma's, call, defi...
# 149559  [reporting, results, physical, talk, drug, use...
# 149560  [always, want, answer, bitch, really, cared, a...
# 149561  [deputies, retrieve, loaded, guns, pounds, mar...
# 149562  [breaking, attorney, general, geoffrey, cox, f...
# 149563          [alcohol, heals, depression, temporarily]
# 149564                                       [drunk, sex]
# 149565  [heard, cocaine, problem, uppers, brother, hug...
# 149566  [si, vous, avez, de, la, vaisselle, faire, app...
# 149567            [portuguese, like, spanish, de, verdad]
#
#                                               stem_tokens
# 0       [buy, spi, put, amd, leav, dsx, alon, love, ge...
# 1       [psychiatrist, forget, call, im, flip, tf, got...
# 2                             [wa, da, person, nun, lose]
# 3       [came, addict, bad, bitch, life, togeth, im, y...
# 4       [go, violent, super, sleazi, democrat, victim,...
# 5       [went, rehab, last, summer, cuz, wa, withdraw,...
# 6       [extrem, aerosmith, voic, im, baack, back, aga...
# 7       [offici, uncomfort, infus, friday, fun, giant,...
# 8                                          [trump, share]
# 9       [never, ever, ever, taken, moron, hed, never, ...
# 10      [like, youtub, video, unsan, bloat, amphetamin...
# 11                        [start, pass, go, long, summer]
# 12      [guess, your, suppos, eat, dinner, snort, meth...
# 13      [put, fresh, basil, extra, spice, ramen, noodl...
# 14      [frequent, angeryesyou, suffer, histrion, pers...
# 15      [demi, lovato, mom, open, escap, abus, first, ...
# 16      [nwa, eazy, abovethelaw, bigpun, biggi, scarfa...
# 17      [peopl, hate, demi, addict, half, yall, pop, b...
# 18      [second, wire, meant, feel, similar, wa, lsd, ...
# 19      [ever, pop, coupl, sub, go, session, nope, ive...
# 20                               [abus, prescript, guess]
# 21      [take, red, ha, win, serious, troubl, hard, be...
# 22       [flight, anxieti, cure, two, mic, ultra, nofear]
# 23      [watch, network, last, month, almost, despair,...
# 24      [panic, attack, hate, take, feel, drag, follow...
# 25      [lead, exposur, extraordinarili, high, incid, ...
# 26      [u, feel, peopl, take, etizolam, usa, truli, n...
# 27      [teen, abus, surgingbaltimor, teen, drug, use,...
# 28                     [blurri, visionyou, probabl, caus]
# 29      [one, know, caus, depress, idea, chemic, imbal...
# ...                                                   ...
# 149538    [aral, kd, nyadepresyong, n, gidem, de, bi, em]
# 149539  [que, pobr, pan, ni, que, la, maraca, desd, el...
# 149540  [small, percentag, peopl, increas, excit, anxi...
# 149541  [scream, never, forget, got, addict, space, on...
# 149542  [good, mean, u, tweak, big, wtf, word, salad, ...
# 149543  [tien, tomando, del, xq, dijo, q, ama, cc, una...
# 149544  [research, mani, start, ritalin, young, age, s...
# 149545  [today, actual, first, day, i'v, ever, taken, ...
# 149546  [c'est, bien, de, te, convaincr, d'avoir, un, ...
# 149547  [realli, mean, treat, better, way, sustain, me...
# 149548  [trump, play, three, dimension, chess, fourth,...
# 149549  [trump, lit, know, russianasset, impeachthemf,...
# 149550  [amber, think, rick, offer, chill, fuck, white...
# 149551  [finch, care, cold, turkey, quit, fluoxetin, f...
# 149552  [know, florida, believ, steroid, abus, provid,...
# 149553  [mg, cymbalta, switch, year, ago, lexapro, cym...
# 149554  [go, pop, hop, tan, bed, forget, almost, chris...
# 149555            [forget, speech, tonight, sniff, sniff]
# 149556   [pop, time, write, music, alll, night, yyeeeuuh]
# 149557  [we'r, hallucin, snort, bring, hallucin, saw, ...
# 149558  [terribl, case, listen, grandma, call, definit...
# 149559  [report, result, physic, talk, drug, use, nasa...
# 149560  [alway, want, answer, bitch, realli, care, anx...
# 149561  [deputi, retriev, load, gun, pound, marijuana,...
# 149562  [break, attorney, general, geoffrey, cox, foun...
# 149563              [alcohol, heal, depress, temporarili]
# 149564                                       [drunk, sex]
# 149565  [heard, cocain, problem, upper, brother, huge,...
# 149566  [si, vous, avez, de, la, vaissell, fair, appel...
# 149567             [portugues, like, spanish, de, verdad]
#
# [149568 rows x 8 columns]

# %%
wnl = WordNetLemmatizer()
def lemmatizer (tokens):
    lemm = [wnl.lemmatize(t, pos='v') for t in tokens]
    return lemm

# %%
tweets_dataset['lemm_tokens'] = tweets_dataset['cln_tokens'].apply(lambda x: lemmatizer(x))

# %%
tweets_dataset
# Out:
#                                                      text  upper  drugName  \
# 0       i am buying spy put amd leaving dsx alone that...      0    Prozac
# 1       if my psychiatrist forgets to call in my adder...      0  Adderall
# 2          i wa da person on xanax i ain have nun to lose      0     Xanax
# 3       came from being a xanax addict to a bad as bit...      0     Xanax
# 4       what is going on with violent and super sleazy...      0  Adderall
# 5       i went to rehab last summer cuz i wa withdraw ...      0     Xanax
# 6       extremely aerosmith voice im baack back on my ...      0    Prozac
# 7       this is officially an uncomfortable xanax infu...      0     Xanax
# 8                           trump is sharing his adderall      0  Adderall
# 9       he never ever not once ever taken adderall mor...      0  Adderall
# 10      i liked a youtube video unsane the bloat amphe...      0       NaN
# 11      start passing out the xanax it going to be a l...      0     Xanax
# 12      i guess youre not supposed to eat xanax for di...      0     Xanax
# 13      me putting fresh basil some extra spice in my ...      0  Adderall
# 14      have frequent angeryesyou suffer from histrion...      0    Prozac
# 15      demi lovatos mom open up about escaping abusiv...      0     Xanax
# 16      nwa eazye abovethelaw bigpun biggie scarface m...      0     Xanax
# 17      people hate on demi for addiction but half of ...      0     Xanax
# 18      secondly by wired i meant i feel similar to a ...      0       NaN
# 19      you ever pop a couple xanax with a sub and the...      0     Xanax
# 20           she abuse her xanax prescription is my guess      0     Xanax
# 21      taking xanax red ha to win or were in serious ...      0     Xanax
# 22      flight anxiety cure xanax and two mic ultras n...      0     Xanax
# 23      i have watched all network for last month and ...      0    Prozac
# 24      i have xanax for panic attack i hate taking it...      0     Xanax
# 25      between lead exposure and the extraordinarily ...      0  Adderall
# 26      how do u feel about people taking etizolam in ...      0     Xanax
# 27      teen xanax abuse is surgingbaltimore teen drug...      0     Xanax
# 28       have blurry visionyou probably have cause prozac      0    Prozac
# 29      no one know what cause depression the idea tha...      0    Prozac
# ...                                                   ...    ...       ...
# 149538   aral kd nyadepresyong n  gidem de bi prozac i em      4    Prozac
# 149539  que pobre pan ni que la  maraca,desde el proza...     55    Prozac
# 149540  very small percentage of people will have incr...      4     Xanax
# 149541  screams i will never forget how she got an add...      0  Adderall
# 149542   is adderall that good i mean u are tweaking b...      6  Adderall
# 149543  me tiene tomando del xanax xq dijo q no me ama...      0     Xanax
# 149544  research how many started out on adderall , or...    103  Adderall
# 149545  today is actually the first day i've ever take...     10    Prozac
# 149546  c'est bien de te convaincre d'avoir un semblan...      1     Xanax
# 149547  not really, i mean we treat them better than m...      3     Xanax
# 149548  trump is playing three dimensional chess in th...      4  Adderall
# 149549  trump is too lit up on adderall to know where ...     15  Adderall
# 149550  amber, i m thinking rick offered you the   xan...      4     Xanax
# 149551  finch, be careful on a cold turkey quit of flu...      5       NaN
# 149552  did you know that florida believes that steroi...      0     Xanax
# 149553   mg of cymbalta  i switched years ago from lex...     10    Prozac
# 149554  going to pop some xanax , hop in a tanning bed...      2     Xanax
# 149555  don't forget your adderall before your speech ...      2  Adderall
# 149556  just popped an adderall time to write music al...     18  Adderall
# 149557  we're you hallucinating?? does snorting addera...     12  Adderall
# 149558  terrible case  did you listen to grandma's  ca...     15     Xanax
# 149559  while reporting results of that physical talk ...      4  Adderall
# 149560  i always want to answer,  bitch if you really ...      2     Xanax
# 149561  deputies retrieve loaded guns, pounds of marij...     10     Xanax
# 149562  breaking  attorney general geoffrey cox has be...     28     Xanax
# 149563  alcohol and xanax heals depression     tempora...      3     Xanax
# 149564                    off a xanax have some drunk sex      2     Xanax
# 149565  i ve heard he had an adderall and cocaine prob...      5  Adderall
# 149566  si vous avez de la vaisselle   faire appelez m...      3     Xanax
# 149567    portuguese is like spanish in xanax   de verdad      8     Xanax
#
#        useless                                             tokens  \
# 0          NaN  [i, am, buying, spy, put, amd, leaving, dsx, a...
# 1          NaN  [if, my, psychiatrist, forgets, to, call, in, ...
# 2          NaN  [i, wa, da, person, on, xanax, i, ain, have, n...
# 3          NaN  [came, from, being, a, xanax, addict, to, a, b...
# 4          NaN  [what, is, going, on, with, violent, and, supe...
# 5          NaN  [i, went, to, rehab, last, summer, cuz, i, wa,...
# 6          NaN  [extremely, aerosmith, voice, im, baack, back,...
# 7          NaN  [this, is, officially, an, uncomfortable, xana...
# 8          NaN                [trump, is, sharing, his, adderall]
# 9          NaN  [he, never, ever, not, once, ever, taken, adde...
# 10         NaN  [i, liked, a, youtube, video, unsane, the, blo...
# 11         NaN  [start, passing, out, the, xanax, it, going, t...
# 12         NaN  [i, guess, youre, not, supposed, to, eat, xana...
# 13         NaN  [me, putting, fresh, basil, some, extra, spice...
# 14         NaN  [have, frequent, angeryesyou, suffer, from, hi...
# 15         NaN  [demi, lovatos, mom, open, up, about, escaping...
# 16         NaN  [nwa, eazye, abovethelaw, bigpun, biggie, scar...
# 17         NaN  [people, hate, on, demi, for, addiction, but, ...
# 18         NaN  [secondly, by, wired, i, meant, i, feel, simil...
# 19         NaN  [you, ever, pop, a, couple, xanax, with, a, su...
# 20         NaN  [she, abuse, her, xanax, prescription, is, my,...
# 21         NaN  [taking, xanax, red, ha, to, win, or, were, in...
# 22         NaN  [flight, anxiety, cure, xanax, and, two, mic, ...
# 23         NaN  [i, have, watched, all, network, for, last, mo...
# 24         NaN  [i, have, xanax, for, panic, attack, i, hate, ...
# 25         NaN  [between, lead, exposure, and, the, extraordin...
# 26         NaN  [how, do, u, feel, about, people, taking, etiz...
# 27         NaN  [teen, xanax, abuse, is, surgingbaltimore, tee...
# 28         NaN  [have, blurry, visionyou, probably, have, caus...
# 29         NaN  [no, one, know, what, cause, depression, the, ...
# ...        ...                                                ...
# 149538     NaN  [aral, kd, nyadepresyong, n, gidem, de, bi, pr...
# 149539     NaN  [que, pobre, pan, ni, que, la, maraca, desde, ...
# 149540     NaN  [very, small, percentage, of, people, will, ha...
# 149541     NaN  [screams, i, will, never, forget, how, she, go...
# 149542     NaN  [is, adderall, that, good, i, mean, u, are, tw...
# 149543     NaN  [me, tiene, tomando, del, xanax, xq, dijo, q, ...
# 149544     NaN  [research, how, many, started, out, on, addera...
# 149545     NaN  [today, is, actually, the, first, day, i've, e...
# 149546     NaN  [c'est, bien, de, te, convaincre, d'avoir, un,...
# 149547     NaN  [not, really, i, mean, we, treat, them, better...
# 149548     NaN  [trump, is, playing, three, dimensional, chess...
# 149549     NaN  [trump, is, too, lit, up, on, adderall, to, kn...
# 149550     NaN  [amber, i, m, thinking, rick, offered, you, th...
# 149551     NaN  [finch, be, careful, on, a, cold, turkey, quit...
# 149552     NaN  [did, you, know, that, florida, believes, that...
# 149553     NaN  [mg, of, cymbalta, i, switched, years, ago, fr...
# 149554     NaN  [going, to, pop, some, xanax, hop, in, a, tann...
# 149555     NaN  [don't, forget, your, adderall, before, your, ...
# 149556     NaN  [just, popped, an, adderall, time, to, write, ...
# 149557     NaN  [we're, you, hallucinating, does, snorting, ad...
# 149558     NaN  [terrible, case, did, you, listen, to, grandma...
# 149559     NaN  [while, reporting, results, of, that, physical...
# 149560     NaN  [i, always, want, to, answer, bitch, if, you, ...
# 149561     NaN  [deputies, retrieve, loaded, guns, pounds, of,...
# 149562     NaN  [breaking, attorney, general, geoffrey, cox, h...
# 149563     NaN  [alcohol, and, xanax, heals, depression, tempo...
# 149564     NaN            [off, a, xanax, have, some, drunk, sex]
# 149565     NaN  [i, ve, heard, he, had, an, adderall, and, coc...
# 149566     NaN  [si, vous, avez, de, la, vaisselle, faire, app...
# 149567     NaN  [portuguese, is, like, spanish, in, xanax, de,...
#
#                                                    ngrams  \
# 0       [i, a, m, b, u, y, i, n, g, s, p, y, p, u, t, ...
# 1       [i, f, m, y, p, s, y, c, h, i, a, t, r, i, s, ...
# 2       [i, w, a, d, a, p, e, r, s, o, n, o, n, x, a, ...
# 3       [c, a, m, e, f, r, o, m, b, e, i, n, g, a, x, ...
# 4       [w, h, a, t, i, s, g, o, i, n, g, o, n, w, i, ...
# 5       [i, w, e, n, t, t, o, r, e, h, a, b, l, a, s, ...
# 6       [e, x, t, r, e, m, e, l, y, a, e, r, o, s, m, ...
# 7       [t, h, i, s, i, s, o, f, f, i, c, i, a, l, l, ...
# 8       [t, r, u, m, p, i, s, s, h, a, r, i, n, g, h, ...
# 9       [h, e, n, e, v, e, r, e, v, e, r, n, o, t, o, ...
# 10      [i, l, i, k, e, d, a, y, o, u, t, u, b, e, v, ...
# 11      [s, t, a, r, t, p, a, s, s, i, n, g, o, u, t, ...
# 12      [i, g, u, e, s, s, y, o, u, r, e, n, o, t, s, ...
# 13      [m, e, p, u, t, t, i, n, g, f, r, e, s, h, b, ...
# 14      [h, a, v, e, f, r, e, q, u, e, n, t, a, n, g, ...
# 15      [d, e, m, i, l, o, v, a, t, o, s, m, o, m, o, ...
# 16      [n, w, a, e, a, z, y, e, a, b, o, v, e, t, h, ...
# 17      [p, e, o, p, l, e, h, a, t, e, o, n, d, e, m, ...
# 18      [s, e, c, o, n, d, l, y, b, y, w, i, r, e, d, ...
# 19      [y, o, u, e, v, e, r, p, o, p, a, c, o, u, p, ...
# 20      [s, h, e, a, b, u, s, e, h, e, r, x, a, n, a, ...
# 21      [t, a, k, i, n, g, x, a, n, a, x, r, e, d, h, ...
# 22      [f, l, i, g, h, t, a, n, x, i, e, t, y, c, u, ...
# 23      [i, h, a, v, e, w, a, t, c, h, e, d, a, l, l, ...
# 24      [i, h, a, v, e, x, a, n, a, x, f, o, r, p, a, ...
# 25      [b, e, t, w, e, e, n, l, e, a, d, e, x, p, o, ...
# 26      [h, o, w, d, o, u, f, e, e, l, a, b, o, u, t, ...
# 27      [t, e, e, n, x, a, n, a, x, a, b, u, s, e, i, ...
# 28      [h, a, v, e, b, l, u, r, r, y, v, i, s, i, o, ...
# 29      [n, o, o, n, e, k, n, o, w, w, h, a, t, c, a, ...
# ...                                                   ...
# 149538  [a, r, a, l, k, d, n, y, a, d, e, p, r, e, s, ...
# 149539  [q, u, e, p, o, b, r, e, p, a, n, n, i, q, u, ...
# 149540  [v, e, r, y, s, m, a, l, l, p, e, r, c, e, n, ...
# 149541  [s, c, r, e, a, m, s, i, w, i, l, l, n, e, v, ...
# 149542  [i, s, a, d, d, e, r, a, l, l, t, h, a, t, g, ...
# 149543  [m, e, t, i, e, n, e, t, o, m, a, n, d, o, d, ...
# 149544  [r, e, s, e, a, r, c, h, h, o, w, m, a, n, y, ...
# 149545  [t, o, d, a, y, i, s, a, c, t, u, a, l, l, y, ...
# 149546  [c, ', e, s, t, b, i, e, n, d, e, t, e, c, o, ...
# 149547  [n, o, t, r, e, a, l, l, y, ,, i, m, e, a, n, ...
# 149548  [t, r, u, m, p, i, s, p, l, a, y, i, n, g, t, ...
# 149549  [t, r, u, m, p, i, s, t, o, o, l, i, t, u, p, ...
# 149550  [a, m, b, e, r, ,, i, m, t, h, i, n, k, i, n, ...
# 149551  [f, i, n, c, h, ,, b, e, c, a, r, e, f, u, l, ...
# 149552  [d, i, d, y, o, u, k, n, o, w, t, h, a, t, f, ...
# 149553  [m, g, o, f, c, y, m, b, a, l, t, a, i, s, w, ...
# 149554  [g, o, i, n, g, t, o, p, o, p, s, o, m, e, x, ...
# 149555  [d, o, n, ', t, f, o, r, g, e, t, y, o, u, r, ...
# 149556  [j, u, s, t, p, o, p, p, e, d, a, n, a, d, d, ...
# 149557  [w, e, ', r, e, y, o, u, h, a, l, l, u, c, i, ...
# 149558  [t, e, r, r, i, b, l, e, c, a, s, e, d, i, d, ...
# 149559  [w, h, i, l, e, r, e, p, o, r, t, i, n, g, r, ...
# 149560  [i, a, l, w, a, y, s, w, a, n, t, t, o, a, n, ...
# 149561  [d, e, p, u, t, i, e, s, r, e, t, r, i, e, v, ...
# 149562  [b, r, e, a, k, i, n, g, a, t, t, o, r, n, e, ...
# 149563  [a, l, c, o, h, o, l, a, n, d, x, a, n, a, x, ...
# 149564  [o, f, f, a, x, a, n, a, x, h, a, v, e, s, o, ...
# 149565  [i, v, e, h, e, a, r, d, h, e, h, a, d, a, n, ...
# 149566  [s, i, v, o, u, s, a, v, e, z, d, e, l, a, v, ...
# 149567  [p, o, r, t, u, g, u, e, s, e, i, s, l, i, k, ...
#
#                                                cln_tokens  \
# 0       [buying, spy, put, amd, leaving, dsx, alone, l...
# 1       [psychiatrist, forgets, call, im, flipping, tf...
# 2                             [wa, da, person, nun, lose]
# 3       [came, addict, bad, bitch, life, together, im,...
# 4       [going, violent, super, sleazy, democrat, vict...
# 5       [went, rehab, last, summer, cuz, wa, withdraw,...
# 6       [extremely, aerosmith, voice, im, baack, back,...
# 7       [officially, uncomfortable, infused, friday, f...
# 8                                        [trump, sharing]
# 9       [never, ever, ever, taken, moron, hed, never, ...
# 10      [liked, youtube, video, unsane, bloat, ampheta...
# 11                  [start, passing, going, long, summer]
# 12      [guess, youre, supposed, eat, dinner, snort, m...
# 13      [putting, fresh, basil, extra, spice, ramen, n...
# 14      [frequent, angeryesyou, suffer, histrionic, pe...
# 15      [demi, lovatos, mom, open, escaping, abusive, ...
# 16      [nwa, eazye, abovethelaw, bigpun, biggie, scar...
# 17      [people, hate, demi, addiction, half, yall, po...
# 18      [secondly, wired, meant, feel, similar, wa, ls...
# 19      [ever, pop, couple, sub, go, session, nope, iv...
# 20                           [abuse, prescription, guess]
# 21      [taking, red, ha, win, serious, trouble, hard,...
# 22      [flight, anxiety, cure, two, mic, ultras, nofear]
# 23      [watched, network, last, month, almost, despai...
# 24      [panic, attack, hate, taking, feel, dragged, f...
# 25      [lead, exposure, extraordinarily, high, incide...
# 26      [u, feel, people, taking, etizolam, usa, truly...
# 27      [teen, abuse, surgingbaltimore, teen, drug, us...
# 28                   [blurry, visionyou, probably, cause]
# 29      [one, know, cause, depression, idea, chemical,...
# ...                                                   ...
# 149538    [aral, kd, nyadepresyong, n, gidem, de, bi, em]
# 149539  [que, pobre, pan, ni, que, la, maraca, desde, ...
# 149540  [small, percentage, people, increased, excitab...
# 149541  [screams, never, forget, got, 'addiction', spa...
# 149542  [good, mean, u, tweaking, bigly, wtf, word, sa...
# 149543  [tiene, tomando, del, xq, dijo, q, ama, cc, un...
# 149544  [research, many, started, ritalin, young, age,...
# 149545  [today, actually, first, day, i've, ever, take...
# 149546  [c'est, bien, de, te, convaincre, d'avoir, un,...
# 149547  [really, mean, treat, better, way, sustainable...
# 149548  [trump, playing, three, dimensional, chess, fo...
# 149549  [trump, lit, know, russianasset, impeachthemf,...
# 149550  [amber, thinking, rick, offered, chill, fuck, ...
# 149551  [finch, careful, cold, turkey, quit, fluoxetin...
# 149552  [know, florida, believes, steroid, abuse, prov...
# 149553  [mg, cymbalta, switched, years, ago, lexapro, ...
# 149554  [going, pop, hop, tanning, bed, forget, almost...
# 149555            [forget, speech, tonight, sniff, sniff]
# 149556  [popped, time, write, music, alll, night, yyee...
# 149557  [we're, hallucinating, snorting, bring, halluc...
# 149558  [terrible, case, listen, grandma's, call, defi...
# 149559  [reporting, results, physical, talk, drug, use...
# 149560  [always, want, answer, bitch, really, cared, a...
# 149561  [deputies, retrieve, loaded, guns, pounds, mar...
# 149562  [breaking, attorney, general, geoffrey, cox, f...
# 149563          [alcohol, heals, depression, temporarily]
# 149564                                       [drunk, sex]
# 149565  [heard, cocaine, problem, uppers, brother, hug...
# 149566  [si, vous, avez, de, la, vaisselle, faire, app...
# 149567            [portuguese, like, spanish, de, verdad]
#
#                                               stem_tokens  \
# 0       [buy, spi, put, amd, leav, dsx, alon, love, ge...
# 1       [psychiatrist, forget, call, im, flip, tf, got...
# 2                             [wa, da, person, nun, lose]
# 3       [came, addict, bad, bitch, life, togeth, im, y...
# 4       [go, violent, super, sleazi, democrat, victim,...
# 5       [went, rehab, last, summer, cuz, wa, withdraw,...
# 6       [extrem, aerosmith, voic, im, baack, back, aga...
# 7       [offici, uncomfort, infus, friday, fun, giant,...
# 8                                          [trump, share]
# 9       [never, ever, ever, taken, moron, hed, never, ...
# 10      [like, youtub, video, unsan, bloat, amphetamin...
# 11                        [start, pass, go, long, summer]
# 12      [guess, your, suppos, eat, dinner, snort, meth...
# 13      [put, fresh, basil, extra, spice, ramen, noodl...
# 14      [frequent, angeryesyou, suffer, histrion, pers...
# 15      [demi, lovato, mom, open, escap, abus, first, ...
# 16      [nwa, eazy, abovethelaw, bigpun, biggi, scarfa...
# 17      [peopl, hate, demi, addict, half, yall, pop, b...
# 18      [second, wire, meant, feel, similar, wa, lsd, ...
# 19      [ever, pop, coupl, sub, go, session, nope, ive...
# 20                               [abus, prescript, guess]
# 21      [take, red, ha, win, serious, troubl, hard, be...
# 22       [flight, anxieti, cure, two, mic, ultra, nofear]
# 23      [watch, network, last, month, almost, despair,...
# 24      [panic, attack, hate, take, feel, drag, follow...
# 25      [lead, exposur, extraordinarili, high, incid, ...
# 26      [u, feel, peopl, take, etizolam, usa, truli, n...
# 27      [teen, abus, surgingbaltimor, teen, drug, use,...
# 28                     [blurri, visionyou, probabl, caus]
# 29      [one, know, caus, depress, idea, chemic, imbal...
# ...                                                   ...
# 149538    [aral, kd, nyadepresyong, n, gidem, de, bi, em]
# 149539  [que, pobr, pan, ni, que, la, maraca, desd, el...
# 149540  [small, percentag, peopl, increas, excit, anxi...
# 149541  [scream, never, forget, got, addict, space, on...
# 149542  [good, mean, u, tweak, big, wtf, word, salad, ...
# 149543  [tien, tomando, del, xq, dijo, q, ama, cc, una...
# 149544  [research, mani, start, ritalin, young, age, s...
# 149545  [today, actual, first, day, i'v, ever, taken, ...
# 149546  [c'est, bien, de, te, convaincr, d'avoir, un, ...
# 149547  [realli, mean, treat, better, way, sustain, me...
# 149548  [trump, play, three, dimension, chess, fourth,...
# 149549  [trump, lit, know, russianasset, impeachthemf,...
# 149550  [amber, think, rick, offer, chill, fuck, white...
# 149551  [finch, care, cold, turkey, quit, fluoxetin, f...
# 149552  [know, florida, believ, steroid, abus, provid,...
# 149553  [mg, cymbalta, switch, year, ago, lexapro, cym...
# 149554  [go, pop, hop, tan, bed, forget, almost, chris...
# 149555            [forget, speech, tonight, sniff, sniff]
# 149556   [pop, time, write, music, alll, night, yyeeeuuh]
# 149557  [we'r, hallucin, snort, bring, hallucin, saw, ...
# 149558  [terribl, case, listen, grandma, call, definit...
# 149559  [report, result, physic, talk, drug, use, nasa...
# 149560  [alway, want, answer, bitch, realli, care, anx...
# 149561  [deputi, retriev, load, gun, pound, marijuana,...
# 149562  [break, attorney, general, geoffrey, cox, foun...
# 149563              [alcohol, heal, depress, temporarili]
# 149564                                       [drunk, sex]
# 149565  [heard, cocain, problem, upper, brother, huge,...
# 149566  [si, vous, avez, de, la, vaissell, fair, appel...
# 149567             [portugues, like, spanish, de, verdad]
#
#                                               lemm_tokens  \
# 0       [buy, spy, put, amd, leave, dsx, alone, lovely...
# 1       [psychiatrist, forget, call, im, flip, tf, get...
# 2                             [wa, da, person, nun, lose]
# 3       [come, addict, bad, bitch, life, together, im,...
# 4       [go, violent, super, sleazy, democrat, victim,...
# 5       [go, rehab, last, summer, cuz, wa, withdraw, n...
# 6       [extremely, aerosmith, voice, im, baack, back,...
# 7       [officially, uncomfortable, infuse, friday, fu...
# 8                                          [trump, share]
# 9       [never, ever, ever, take, moron, hed, never, t...
# 10      [like, youtube, video, unsane, bloat, amphetam...
# 11                        [start, pass, go, long, summer]
# 12      [guess, youre, suppose, eat, dinner, snort, me...
# 13      [put, fresh, basil, extra, spice, ramen, noodl...
# 14      [frequent, angeryesyou, suffer, histrionic, pe...
# 15      [demi, lovatos, mom, open, escape, abusive, fi...
# 16      [nwa, eazye, abovethelaw, bigpun, biggie, scar...
# 17      [people, hate, demi, addiction, half, yall, po...
# 18      [secondly, wire, mean, feel, similar, wa, lsd,...
# 19      [ever, pop, couple, sub, go, session, nope, iv...
# 20                           [abuse, prescription, guess]
# 21      [take, red, ha, win, serious, trouble, hard, b...
# 22      [flight, anxiety, cure, two, mic, ultras, nofear]
# 23      [watch, network, last, month, almost, despair,...
# 24      [panic, attack, hate, take, feel, drag, follow...
# 25      [lead, exposure, extraordinarily, high, incide...
# 26      [u, feel, people, take, etizolam, usa, truly, ...
# 27      [teen, abuse, surgingbaltimore, teen, drug, us...
# 28                   [blurry, visionyou, probably, cause]
# 29      [one, know, cause, depression, idea, chemical,...
# ...                                                   ...
# 149538    [aral, kd, nyadepresyong, n, gidem, de, bi, em]
# 149539  [que, pobre, pan, ni, que, la, maraca, desde, ...
# 149540  [small, percentage, people, increase, excitabi...
# 149541  [scream, never, forget, get, 'addiction', spac...
# 149542  [good, mean, u, tweak, bigly, wtf, word, salad...
# 149543  [tiene, tomando, del, xq, dijo, q, ama, cc, un...
# 149544  [research, many, start, ritalin, young, age, s...
# 149545  [today, actually, first, day, i've, ever, take...
# 149546  [c'est, bien, de, te, convaincre, d'avoir, un,...
# 149547  [really, mean, treat, better, way, sustainable...
# 149548  [trump, play, three, dimensional, chess, fourt...
# 149549  [trump, light, know, russianasset, impeachthem...
# 149550  [amber, think, rick, offer, chill, fuck, white...
# 149551  [finch, careful, cold, turkey, quit, fluoxetin...
# 149552  [know, florida, believe, steroid, abuse, provi...
# 149553  [mg, cymbalta, switch, years, ago, lexapro, cy...
# 149554  [go, pop, hop, tan, bed, forget, almost, chris...
# 149555            [forget, speech, tonight, sniff, sniff]
# 149556   [pop, time, write, music, alll, night, yyeeeuuh]
# 149557  [we're, hallucinate, snort, bring, hallucinati...
# 149558  [terrible, case, listen, grandma's, call, defi...
# 149559  [report, result, physical, talk, drug, use, na...
# 149560  [always, want, answer, bitch, really, care, an...
# 149561  [deputies, retrieve, load, gun, pound, marijua...
# 149562  [break, attorney, general, geoffrey, cox, find...
# 149563           [alcohol, heal, depression, temporarily]
# 149564                                       [drink, sex]
# 149565  [hear, cocaine, problem, uppers, brother, huge...
# 149566  [si, vous, avez, de, la, vaisselle, faire, app...
# 149567            [portuguese, like, spanish, de, verdad]
#
#                                                   unusual
# 0                                              {dsx, amd}
# 1                                           {im, tf, smh}
# 2                                                      {}
# 3                                                    {im}
# 4                                       {ovaloffice, wtf}
# 5                {stepdad, rehab, minookaconfesions, cuz}
# 6                        {im, baack, aerosmith, agaaaiin}
# 7                                                      {}
# 8                                                      {}
# 9                                    {hed, google, youll}
# 10                                              {youtube}
# 11                                                     {}
# 12                                     {meth, youre, eay}
# 13                                            {ramen, bc}
# 14                                          {angeryesyou}
# 15                                         {lovatos, mom}
# 16      {frommusicworth, eazye, alot, yomtvrapsi, chan...
# 17                                                 {yall}
# 18                              {lsd, subperceptual, ive}
# 19                                                  {ive}
# 20                                                     {}
# 21                                          {im, shalala}
# 22                                  {nofear, mic, ultras}
# 23                                 {cnn, msm, msnbc, etc}
# 24                                            {trazodone}
# 25                               {meth, adhd, smallscale}
# 26      {med, etizolam, benzosplease, mentalhealth, va...
# 27                                     {surgingbaltimore}
# 28                                            {visionyou}
# 29                                                     {}
# ...                                                   ...
# 149538               {nyadepresyong, gidem, kd, bi, aral}
# 149539  {hdsrpm, com, puro, sta, desmadre, canallita, ...
# 149540        {benzodiazepines, imbalances, deficiencies}
# 149541                                                 {}
# 149542                 {fuck, com, nqsvapbmx, wtf, bigly}
# 149543  {tomando, mirada, deja, marcada, xq, dijo, cc,...
# 149544             {andrewpollackf, ritalin, obamas, com}
# 149545                    {antidepressant, maoi, md, yay}
# 149546  {chappe, qui, et, des, convaincre, lol, person...
# 149547                                        {countries}
# 149548                       {pelosi, com, davidbrodycbn}
# 149549  {impeachthemf, trumpresign, russianasset, com,...
# 149550                                             {fuck}
# 149551                                 {fluoxetine, fuck}
# 149552                                                 {}
# 149553               {meds, mg, years, lexapro, cymbalta}
# 149554                                                 {}
# 149555                                                 {}
# 149556                                   {alll, yyeeeuuh}
# 149557  {thamendmentnow, mitchshutdown, hallucinations...
# 149558                                          {dr, imo}
# 149559                              {com, jeffreyguterma}
# 149560                                         {klonopon}
# 149561      {deputies, com, houston, dlvr, otwzcfjq, qsj}
# 149562  {ejfelkvr, com, tourbus, xansgonbetrayyou, con...
# 149563                                                 {}
# 149564                                                 {}
# 149565                                                 {}
# 149566  {jsuis, vaisselle, est, appelez, faire, vous, ...
# 149567                                           {verdad}
#
# [149568 rows x 10 columns]

# %%
english_vocab = set(w.lower() for w in words.words())
def unusual(lemm_tokens):
    text_vocab = set(w.lower() for w in lemm_tokens if w.isalpha()) # Note .isalpha() removes punctuation tokens. However, tokens with a hyphen like 'browser-based' are totally skipped over because .isalpha() would be false.
    unusual = text_vocab.difference(english_vocab)
    return unusual

# %%
tweets_dataset['unusual'] = tweets_dataset['lemm_tokens'].apply(lambda x: unusual(x))

# %%
import nltk
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     /Users/saeedahmadgill/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
tweets_dataset.to_csv("../output/final_tweets_dataset_all.csv", index=False)
